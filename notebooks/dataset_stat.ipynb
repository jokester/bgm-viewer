# %%
import duckdb
import os
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/media/nvme1-fast/home-mono/Projects/bgm-archive/notebooks')

# %%
duckdb.sql("""
           SELECT *
            FROM read_json_auto('../dataset/subject.jsonlines') AS subjects
            -- GROUP BY date
            LIMIT 200
           """).df()
# Out:
#       id  type                            name              name_cn  \
# 0      1     1                        第一次的親密接觸             第一次的亲密接触
# 1      4     4                        メタルスラッグ7                合金弹头7
# 2      6     4                 Team Fortress 2                军团要塞2
# 3      7     4             Unreal Tournament 3               虚幻竞技场3
# 4      8     2               コードギアス 反逆のルルーシュR2  Code Geass 反叛的鲁路修R2
# ..   ...   ...                             ...                  ...
# 195  213     4             nintendogs チワワ&フレンズ         任天狗：吉娃娃与它的朋友
# 196  214     4  Nintendogs Dalmatian & Friends         任天狗：大麦町与它的朋友
# 197  215     4            nintendogs ダックス&フレンズ         任天狗：腊肠犬与它的朋友
# 198  216     4                   Drawn to Life
# 199  217     4            ドラゴンクエストモンスターズ ジョーカー      勇者斗恶龙 怪兽篇 Joker
#
#                                                infobox  platform  \
# 0    {{Infobox animanga/Novel\r\n|中文名= 第一次的亲密接触\r\n...      1002
# ...
