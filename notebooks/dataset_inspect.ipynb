# %%
import duckdb
import os
from pathlib import Path

Path.cwd()

# %%
from bgm_archive.loader import WikiArchiveLoader, model

# %%
from itertools import islice


loader = WikiArchiveLoader("../dataset/dump-2025-06-03.210251Z.zip")
for s in islice(loader.subjects(), 1):
    print(s)
